# %%
import torch
import torch.optim as optim
import torch.nn as nn
import pandas as pd
import numpy as np
import tqdm
from seqeval.metrics import f1_score

torch.manual_seed(42)

# %%
train = pd.read_csv('data/train', header = None, names = ['idx','word','tag'], sep ='\s',na_values=['<NAN>'], keep_default_na=False)
train.head(20)
# Out:
# <ipython-input-106-6b8333576978>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train = pd.read_csv('data/train', header = None, names = ['idx','word','tag'], sep ='\s',na_values=['<NAN>'], keep_default_na=False)
#     idx        word     tag
# 0     1          EU   B-ORG
# 1     2     rejects       O
# 2     3      German  B-MISC
# 3     4        call       O
# 4     5          to       O
# 5     6     boycott       O
# 6     7     British  B-MISC
# 7     8        lamb       O
# 8     9           .       O
# 9     1       Peter   B-PER
# 10    2   Blackburn   I-PER
# 11    1    BRUSSELS   B-LOC
# 12    2  1996-08-22       O
# 13    1         The       O
# 14    2    European   B-ORG
# 15    3  Commission   I-ORG
# 16    4        said       O
# 17    5          on       O
# 18    6    Thursday       O
# 19    7          it       O

# %%
dev = pd.read_csv('data/dev', header = None, names = ['idx','word','tag'], sep = '\s',na_values=['<NAN>'], keep_default_na=False)
dev.head(20)
# Out:
# <ipython-input-107-31493b5bc1a0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   dev = pd.read_csv('data/dev', header = None, names = ['idx','word','tag'], sep = '\s',na_values=['<NAN>'], keep_default_na=False)
#     idx            word     tag
# 0     1         CRICKET       O
# 1     2               -       O
# 2     3  LEICESTERSHIRE   B-ORG
# 3     4            TAKE       O
# 4     5            OVER       O
# 5     6              AT       O
# 6     7             TOP       O
# 7     8           AFTER       O
# 8     9         INNINGS       O
# 9    10         VICTORY       O
# 10   11               .       O
# 11    1          LONDON   B-LOC
# 12    2      1996-08-30       O
# 13    1            West  B-MISC
# 14    2          Indian  I-MISC
# 15    3     all-rounder       O
# 16    4            Phil   B-PER
# 17    5         Simmons   I-PER
# 18    6            took       O
# 19    7            four       O

# %%
test = pd.read_csv('data/test', header = None, names = ['idx','word'], sep = '\s',na_values=['<NAN>'], keep_default_na=False)
test.head(20)
# Out:
# <ipython-input-108-f3dca57ae913>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test = pd.read_csv('data/test', header = None, names = ['idx','word'], sep = '\s',na_values=['<NAN>'], keep_default_na=False)
#     idx        word
# 0     1      SOCCER
# 1     2           -
# 2     3       JAPAN
# 3     4         GET
# 4     5       LUCKY
# 5     6         WIN
# 6     7           ,
# 7     8       CHINA
# 8     9          IN
# 9    10    SURPRISE
# 10   11      DEFEAT
# 11   12           .
# 12    1       Nadim
# 13    2       Ladki
# 14    1      AL-AIN
# 15    2           ,
# 16    3      United
# 17    4        Arab
# 18    5    Emirates
# 19    6  1996-12-06

# %%
vocab_dict = {}
for word in train['word'].values.tolist():
    vocab_dict[word] = vocab_dict.get(word,0) + 1

keys = list(vocab_dict.keys())
for word in keys:
    if vocab_dict[word] < 2:
        vocab_dict['<unk>'] = vocab_dict.get('<unk>',0) + vocab_dict[word]
        del vocab_dict[word]
        
word_to_idx = {}
for i,word in enumerate(sorted(list(vocab_dict.keys()))):
    word_to_idx[word] = i
unique_tags = set(train['tag'].values.tolist())
tag_to_idx = {}
idx_to_tag = {}
for i,tag in enumerate(sorted(unique_tags)):
    tag_to_idx[tag] = i
    idx_to_tag[i] = tag
unique_tags
# Out:
# {'B-LOC', 'B-MISC', 'B-ORG', 'B-PER', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O'}

# %%
tag_to_idx
# Out:
# {'B-LOC': 0,
#  'B-MISC': 1,
#  'B-ORG': 2,
#  'B-PER': 3,
#  'I-LOC': 4,
#  'I-MISC': 5,
#  'I-ORG': 6,
#  'I-PER': 7,
#  'O': 8}

# %%
idx_to_tag
# Out:
# {0: 'B-LOC',
#  1: 'B-MISC',
#  2: 'B-ORG',
#  3: 'B-PER',
#  4: 'I-LOC',
#  5: 'I-MISC',
#  6: 'I-ORG',
#  7: 'I-PER',
#  8: 'O'}

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %%
def make_data(df,vocab_dict):
    sentences = []
    sentence_tags = []
    tags = []
    sentence = None
    for row in df.values.tolist():
        if row[0] == 1:
            if sentence:
                sentence_tags.append(tags)
                sentences.append(sentence)
            sentence = []
            tags = []
        if row[1] not in vocab_dict:
            sentence.append('<unk>')
        else:
            sentence.append(row[1])
        tags.append(row[2])
    sentence_tags.append(tags)
    sentences.append(sentence)
    return list(zip(sentences,sentence_tags))

# %%
training_data = make_data(train,vocab_dict)
validation_data = make_data(dev,vocab_dict)

# %%
training_data
# Out:
# [(['EU', '<unk>', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'],
#   ['B-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'B-MISC', 'O', 'O']),
#  (['Peter', 'Blackburn'], ['B-PER', 'I-PER']),
#  (['BRUSSELS', '1996-08-22'], ['B-LOC', 'O']),
#  (['The',
#    'European',
#    'Commission',
#    'said',
#    'on',
#    'Thursday',
#    'it',
#    'disagreed',
#    'with',
#    'German',
#    'advice',
#    'to',
#    'consumers',
#    'to',
#    '<unk>',
#    'British',
#    'lamb',
#    'until',
#    'scientists',
#    'determine',
#    'whether',
#    'mad',
#    'cow',
#    'disease',
#    'can',
#    'be',
#    'transmitted',
#    'to',
#    'sheep',
#    '.'],
#   ['O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Germany',
#    "'s",
#    'representative',
#    'to',
#    'the',
#    'European',
#    'Union',
#    "'s",
#    'veterinary',
#    'committee',
#    'Werner',
#    'Zwingmann',
#    'said',
#    'on',
#    'Wednesday',
#    'consumers',
#    'should',
#    'buy',
#    'sheepmeat',
#    'from',
#    'countries',
#    'other',
#    'than',
#    'Britain',
#    'until',
#    'the',
#    'scientific',
#    'advice',
#    'was',
#    '<unk>',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['"',
#    'We',
#    'do',
#    "n't",
#    'support',
#    'any',
#    'such',
#    'recommendation',
#    'because',
#    'we',
#    'do',
#    "n't",
#    'see',
#    'any',
#    'grounds',
#    'for',
#    'it',
#    ',',
#    '"',
#    'the',
#    'Commission',
#    "'s",
#    'chief',
#    'spokesman',
#    '<unk>',
#    'van',
#    'der',
#    '<unk>',
#    'told',
#    'a',
#    'news',
#    'briefing',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['He',
#    'said',
#    'further',
#    'scientific',
#    'study',
#    'was',
#    'required',
#    'and',
#    'if',
#    'it',
#    'was',
#    'found',
#    'that',
#    'action',
#    'was',
#    'needed',
#    'it',
#    'should',
#    'be',
#    'taken',
#    'by',
#    'the',
#    'European',
#    'Union',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O']),
#  (['He',
#    'said',
#    'a',
#    'proposal',
#    'last',
#    'month',
#    'by',
#    'EU',
#    'Farm',
#    'Commissioner',
#    'Franz',
#    'Fischler',
#    'to',
#    'ban',
#    'sheep',
#    'brains',
#    ',',
#    'spleens',
#    'and',
#    'spinal',
#    'cords',
#    'from',
#    'the',
#    'human',
#    'and',
#    'animal',
#    'food',
#    'chains',
#    'was',
#    'a',
#    'highly',
#    'specific',
#    'and',
#    '<unk>',
#    'move',
#    'to',
#    'protect',
#    'human',
#    'health',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Fischler',
#    'proposed',
#    '<unk>',
#    'measures',
#    'after',
#    'reports',
#    'from',
#    'Britain',
#    'and',
#    'France',
#    'that',
#    'under',
#    'laboratory',
#    'conditions',
#    'sheep',
#    'could',
#    'contract',
#    'Bovine',
#    'Spongiform',
#    'Encephalopathy',
#    '(',
#    'BSE',
#    ')',
#    '--',
#    'mad',
#    'cow',
#    'disease',
#    '.'],
#   ['B-PER',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'I-MISC',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['But',
#    'Fischler',
#    'agreed',
#    'to',
#    'review',
#    'his',
#    'proposal',
#    'after',
#    'the',
#    'EU',
#    "'s",
#    'standing',
#    'veterinary',
#    'committee',
#    ',',
#    '<unk>',
#    'animal',
#    'health',
#    'officials',
#    ',',
#    'questioned',
#    'if',
#    'such',
#    'action',
#    'was',
#    'justified',
#    'as',
#    'there',
#    'was',
#    'only',
#    'a',
#    'slight',
#    'risk',
#    'to',
#    'human',
#    'health',
#    '.'],
#   ['O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Spanish',
#    'Farm',
#    'Minister',
#    '<unk>',
#    'de',
#    '<unk>',
#    'had',
#    'earlier',
#    'accused',
#    'Fischler',
#    'at',
#    'an',
#    'EU',
#    'farm',
#    'ministers',
#    "'",
#    'meeting',
#    'of',
#    'causing',
#    '<unk>',
#    'alarm',
#    'through',
#    '"',
#    'dangerous',
#    '<unk>',
#    '.',
#    '"'],
#   ['B-MISC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['.'], ['O']),
#  (['Only',
#    'France',
#    'and',
#    'Britain',
#    'backed',
#    'Fischler',
#    "'s",
#    'proposal',
#    '.'],
#   ['O', 'B-LOC', 'O', 'B-LOC', 'O', 'B-PER', 'O', 'O', 'O']),
#  (['The',
#    'EU',
#    "'s",
#    'scientific',
#    'veterinary',
#    'and',
#    '<unk>',
#    'committees',
#    'are',
#    'due',
#    'to',
#    're-examine',
#    'the',
#    'issue',
#    'early',
#    'next',
#    'month',
#    'and',
#    'make',
#    'recommendations',
#    'to',
#    'the',
#    'senior',
#    'veterinary',
#    'officials',
#    '.'],
#   ['O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Sheep',
#    'have',
#    'long',
#    'been',
#    'known',
#    'to',
#    'contract',
#    'scrapie',
#    ',',
#    'a',
#    'brain-wasting',
#    'disease',
#    'similar',
#    'to',
#    'BSE',
#    'which',
#    'is',
#    'believed',
#    'to',
#    'have',
#    'been',
#    'transferred',
#    'to',
#    'cattle',
#    'through',
#    'feed',
#    'containing',
#    'animal',
#    'waste',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['British',
#    'farmers',
#    'denied',
#    'on',
#    'Thursday',
#    'there',
#    'was',
#    'any',
#    'danger',
#    'to',
#    'human',
#    'health',
#    'from',
#    'their',
#    'sheep',
#    ',',
#    'but',
#    'expressed',
#    'concern',
#    'that',
#    'German',
#    'government',
#    'advice',
#    'to',
#    'consumers',
#    'to',
#    'avoid',
#    'British',
#    'lamb',
#    'might',
#    'influence',
#    'consumers',
#    'across',
#    'Europe',
#    '.'],
#   ['B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']),
#  (['"',
#    'What',
#    'we',
#    'have',
#    'to',
#    'be',
#    'extremely',
#    '<unk>',
#    'of',
#    'is',
#    'how',
#    'other',
#    'countries',
#    'are',
#    'going',
#    'to',
#    'take',
#    'Germany',
#    "'s",
#    'lead',
#    ',',
#    '"',
#    'Welsh',
#    'National',
#    'Farmers',
#    "'",
#    'Union',
#    '(',
#    '<unk>',
#    ')',
#    'chairman',
#    'John',
#    'Lloyd',
#    'Jones',
#    'said',
#    'on',
#    'BBC',
#    'radio',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O']),
#  (['Bonn',
#    'has',
#    'led',
#    'efforts',
#    'to',
#    'protect',
#    'public',
#    'health',
#    'after',
#    'consumer',
#    'confidence',
#    'collapsed',
#    'in',
#    'March',
#    'after',
#    'a',
#    'British',
#    'report',
#    'suggested',
#    'humans',
#    'could',
#    'contract',
#    'an',
#    'illness',
#    'similar',
#    'to',
#    'mad',
#    'cow',
#    'disease',
#    'by',
#    'eating',
#    'contaminated',
#    'beef',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Germany',
#    'imported',
#    '47,600',
#    'sheep',
#    'from',
#    'Britain',
#    'last',
#    'year',
#    ',',
#    'nearly',
#    'half',
#    'of',
#    'total',
#    'imports',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['It',
#    'brought',
#    'in',
#    '4,275',
#    'tonnes',
#    'of',
#    'British',
#    'mutton',
#    ',',
#    'some',
#    '10',
#    'percent',
#    'of',
#    'overall',
#    'imports',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['<unk>',
#    'Hendrix',
#    'song',
#    'draft',
#    'sells',
#    'for',
#    'almost',
#    '$',
#    '17,000',
#    '.'],
#   ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['LONDON', '1996-08-22'], ['B-LOC', 'O']),
#  (['A',
#    'rare',
#    'early',
#    '<unk>',
#    'draft',
#    'of',
#    'a',
#    'song',
#    'by',
#    'U.S.',
#    'guitar',
#    '<unk>',
#    '<unk>',
#    'Hendrix',
#    'was',
#    'sold',
#    'for',
#    'almost',
#    '$',
#    '17,000',
#    'on',
#    'Thursday',
#    'at',
#    'an',
#    'auction',
#    'of',
#    'some',
#    'of',
#    'the',
#    'late',
#    '<unk>',
#    "'s",
#    'favourite',
#    '<unk>',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['A',
#    'Florida',
#    'restaurant',
#    'paid',
#    '<unk>',
#    'pounds',
#    '(',
#    '$',
#    '<unk>',
#    ')',
#    'for',
#    'the',
#    'draft',
#    'of',
#    '"',
#    'Ai',
#    "n't",
#    'no',
#    'telling',
#    '"',
#    ',',
#    'which',
#    'Hendrix',
#    '<unk>',
#    'on',
#    'a',
#    'piece',
#    'of',
#    'London',
#    'hotel',
#    'stationery',
#    'in',
#    'late',
#    '1966',
#    '.'],
#   ['O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'I-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['At',
#    'the',
#    'end',
#    'of',
#    'a',
#    'January',
#    '1967',
#    'concert',
#    'in',
#    'the',
#    'English',
#    'city',
#    'of',
#    'Nottingham',
#    'he',
#    'threw',
#    'the',
#    'sheet',
#    'of',
#    'paper',
#    'into',
#    'the',
#    'audience',
#    ',',
#    'where',
#    'it',
#    'was',
#    '<unk>',
#    'by',
#    'a',
#    'fan',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Buyers',
#    'also',
#    'snapped',
#    'up',
#    '16',
#    'other',
#    'items',
#    'that',
#    'were',
#    'put',
#    'up',
#    'for',
#    'auction',
#    'by',
#    'Hendrix',
#    "'s",
#    'former',
#    'girlfriend',
#    'Kathy',
#    '<unk>',
#    ',',
#    'who',
#    'lived',
#    'with',
#    'him',
#    'from',
#    '1966',
#    'to',
#    '1969',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['They',
#    'included',
#    'a',
#    'black',
#    '<unk>',
#    'and',
#    'mother',
#    'of',
#    '<unk>',
#    '<unk>',
#    'box',
#    'used',
#    'by',
#    'Hendrix',
#    'to',
#    'store',
#    'his',
#    'drugs',
#    ',',
#    'which',
#    'an',
#    'anonymous',
#    'Australian',
#    '<unk>',
#    'bought',
#    'for',
#    '<unk>',
#    'pounds',
#    '(',
#    '$',
#    '<unk>',
#    ')',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['The',
#    '<unk>',
#    'died',
#    'of',
#    'a',
#    'drugs',
#    '<unk>',
#    'in',
#    '1970',
#    'aged',
#    '27',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['China', 'says', 'Taiwan', '<unk>', 'atmosphere', 'for', 'talks', '.'],
#   ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']),
#  (['BEIJING', '1996-08-22'], ['B-LOC', 'O']),
#  (['China',
#    'on',
#    'Thursday',
#    'accused',
#    'Taipei',
#    'of',
#    'spoiling',
#    'the',
#    'atmosphere',
#    'for',
#    'a',
#    'resumption',
#    'of',
#    'talks',
#    'across',
#    'the',
#    'Taiwan',
#    'Strait',
#    'with',
#    'a',
#    'visit',
#    'to',
#    'Ukraine',
#    'by',
#    'Taiwanese',
#    'Vice',
#    'President',
#    'Lien',
#    'Chan',
#    'this',
#    'week',
#    'that',
#    'infuriated',
#    'Beijing',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']),
#  (['Speaking',
#    'only',
#    'hours',
#    'after',
#    'Chinese',
#    'state',
#    'media',
#    'said',
#    'the',
#    'time',
#    'was',
#    'right',
#    'to',
#    'engage',
#    'in',
#    'political',
#    'talks',
#    'with',
#    'Taiwan',
#    ',',
#    'Foreign',
#    'Ministry',
#    'spokesman',
#    'Shen',
#    '<unk>',
#    'told',
#    'Reuters',
#    ':',
#    '"',
#    'The',
#    'necessary',
#    'atmosphere',
#    'for',
#    'the',
#    'opening',
#    'of',
#    'the',
#    'talks',
#    'has',
#    'been',
#    'disrupted',
#    'by',
#    'the',
#    'Taiwan',
#    'authorities',
#    '.',
#    '"'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O']),
#  (['State',
#    'media',
#    'quoted',
#    'China',
#    "'s",
#    'top',
#    'negotiator',
#    'with',
#    'Taipei',
#    ',',
#    'Tang',
#    'Shubei',
#    ',',
#    'as',
#    'telling',
#    'a',
#    'visiting',
#    'group',
#    'from',
#    'Taiwan',
#    'on',
#    'Wednesday',
#    'that',
#    'it',
#    'was',
#    'time',
#    'for',
#    'the',
#    'rivals',
#    'to',
#    'hold',
#    'political',
#    'talks',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['"',
#    'Now',
#    'is',
#    'the',
#    'time',
#    'for',
#    'the',
#    'two',
#    'sides',
#    'to',
#    'engage',
#    'in',
#    'political',
#    'talks',
#    '...'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['that',
#    'is',
#    'to',
#    'end',
#    'the',
#    'state',
#    'of',
#    'hostility',
#    ',',
#    '"',
#    'Thursday',
#    "'s",
#    'overseas',
#    'edition',
#    'of',
#    'the',
#    'People',
#    "'s",
#    'Daily',
#    'quoted',
#    'Tang',
#    'as',
#    'saying',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O']),
#  (['The',
#    'foreign',
#    'ministry',
#    "'s",
#    'Shen',
#    'told',
#    'Reuters',
#    'Television',
#    'in',
#    'an',
#    'interview',
#    'he',
#    'had',
#    'read',
#    'reports',
#    'of',
#    'Tang',
#    "'s",
#    'comments',
#    'but',
#    'gave',
#    'no',
#    'details',
#    'of',
#    'why',
#    'the',
#    'negotiator',
#    'had',
#    'considered',
#    'the',
#    'time',
#    'right',
#    'for',
#    'talks',
#    'with',
#    'Taiwan',
#    ',',
#    'which',
#    'Beijing',
#    '<unk>',
#    'a',
#    'renegade',
#    'province',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['China',
#    ',',
#    'which',
#    'has',
#    'long',
#    'opposed',
#    'all',
#    'Taipei',
#    'efforts',
#    'to',
#    'gain',
#    'greater',
#    'international',
#    'recognition',
#    ',',
#    'was',
#    'infuriated',
#    'by',
#    'a',
#    'visit',
#    'to',
#    'Ukraine',
#    'this',
#    'week',
#    'by',
#    'Taiwanese',
#    'Vice',
#    'President',
#    'Lien',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'B-PER',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['China', 'says', 'time', 'right', 'for', 'Taiwan', 'talks', '.'],
#   ['B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']),
#  (['BEIJING', '1996-08-22'], ['B-LOC', 'O']),
#  (['China',
#    'has',
#    'said',
#    'it',
#    'was',
#    'time',
#    'for',
#    'political',
#    'talks',
#    'with',
#    'Taiwan',
#    'and',
#    'that',
#    'the',
#    'rival',
#    'island',
#    'should',
#    'take',
#    'practical',
#    'steps',
#    'towards',
#    'that',
#    'goal',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['<unk>',
#    'should',
#    'be',
#    'held',
#    'to',
#    'set',
#    'the',
#    'time',
#    'and',
#    '<unk>',
#    'of',
#    'the',
#    'talks',
#    ',',
#    'the',
#    'official',
#    'Xinhua',
#    'news',
#    'agency',
#    'quoted',
#    'Tang',
#    'Shubei',
#    ',',
#    'executive',
#    'vice',
#    'chairman',
#    'of',
#    'the',
#    'Association',
#    'for',
#    'Relations',
#    '<unk>',
#    'the',
#    'Taiwan',
#    'Straits',
#    ',',
#    'as',
#    'saying',
#    'late',
#    'on',
#    'Wednesday',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['German',
#    'July',
#    'car',
#    'registrations',
#    'up',
#    '14.2',
#    'pct',
#    'yr',
#    '/',
#    'yr',
#    '.'],
#   ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['FRANKFURT', '1996-08-22'], ['B-LOC', 'O']),
#  (['German',
#    '<unk>',
#    'registrations',
#    'of',
#    'motor',
#    'vehicles',
#    'jumped',
#    '14.2',
#    'percent',
#    'in',
#    'July',
#    'this',
#    'year',
#    'from',
#    'the',
#    'year-earlier',
#    'period',
#    ',',
#    'the',
#    'Federal',
#    'office',
#    'for',
#    'motor',
#    'vehicles',
#    'said',
#    'on',
#    'Thursday',
#    '.'],
#   ['B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['The',
#    'office',
#    'said',
#    '<unk>',
#    'new',
#    'cars',
#    'were',
#    'registered',
#    'in',
#    'July',
#    '1996',
#    '--',
#    '<unk>',
#    'passenger',
#    'cars',
#    'and',
#    '<unk>',
#    'trucks',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['The',
#    'figures',
#    'represent',
#    'a',
#    '<unk>',
#    'percent',
#    'increase',
#    'for',
#    'passenger',
#    'cars',
#    'and',
#    'a',
#    '2.2',
#    'percent',
#    'decline',
#    'for',
#    'trucks',
#    'from',
#    'July',
#    '1995',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['<unk>',
#    'registration',
#    'rose',
#    '<unk>',
#    'percent',
#    'in',
#    'the',
#    'period',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['The',
#    'growth',
#    'was',
#    'partly',
#    'due',
#    'to',
#    'an',
#    'increased',
#    'number',
#    'of',
#    'Germans',
#    'buying',
#    'German',
#    'cars',
#    'abroad',
#    ',',
#    'while',
#    'manufacturers',
#    'said',
#    'that',
#    'domestic',
#    'demand',
#    'was',
#    'weak',
#    ',',
#    'the',
#    'federal',
#    'office',
#    'said',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Almost',
#    'all',
#    'German',
#    'car',
#    'manufacturers',
#    'posted',
#    'gains',
#    'in',
#    'registration',
#    'numbers',
#    'in',
#    'the',
#    'period',
#    '.'],
#   ['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Volkswagen',
#    'AG',
#    'won',
#    '<unk>',
#    'registrations',
#    ',',
#    'slightly',
#    'more',
#    'than',
#    'a',
#    'quarter',
#    'of',
#    'the',
#    'total',
#    '.'],
#   ['B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['<unk>',
#    'AG',
#    'together',
#    'with',
#    'General',
#    'Motors',
#    'came',
#    'in',
#    'second',
#    'place',
#    'with',
#    '<unk>',
#    'registrations',
#    ',',
#    '<unk>',
#    'percent',
#    'of',
#    'the',
#    'overall',
#    'figure',
#    '.'],
#   ['B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Third',
#    'was',
#    'Ford',
#    'with',
#    '<unk>',
#    'registrations',
#    ',',
#    'or',
#    '11.7',
#    'percent',
#    '.'],
#   ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Only',
#    'Seat',
#    'and',
#    'Porsche',
#    'had',
#    'fewer',
#    'registrations',
#    'in',
#    'July',
#    '1996',
#    'compared',
#    'to',
#    'last',
#    'year',
#    "'s",
#    'July',
#    '.'],
#   ['O',
#    'B-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Seat',
#    'posted',
#    '<unk>',
#    'registrations',
#    'compared',
#    'with',
#    '<unk>',
#    'registrations',
#    'in',
#    'July',
#    'a',
#    'year',
#    'earlier',
#    '.'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Porsche',
#    "'s",
#    'registrations',
#    'fell',
#    'to',
#    '<unk>',
#    'from',
#    '<unk>',
#    '.'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'TO',
#    'PM',
#    'FOR',
#    '<unk>',
#    '.'],
#   ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['ATHENS', '1996-08-22'], ['B-LOC', 'O']),
#  (['The',
#    'Greek',
#    'socialist',
#    'party',
#    "'s",
#    'executive',
#    'bureau',
#    'gave',
#    'the',
#    'green',
#    'light',
#    'to',
#    'Prime',
#    'Minister',
#    'Costas',
#    'Simitis',
#    'to',
#    'call',
#    'snap',
#    'elections',
#    ',',
#    'its',
#    'general',
#    'secretary',
#    'Costas',
#    'Skandalidis',
#    'told',
#    'reporters',
#    '.'],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O']),
#  (['Prime',
#    'Minister',
#    'Costas',
#    'Simitis',
#    'is',
#    'going',
#    'to',
#    'make',
#    'an',
#    'official',
#    'announcement',
#    'after',
#    'a',
#    'cabinet',
#    'meeting',
#    'later',
#    'on',
#    'Thursday',
#    ',',
#    'said',
#    'Skandalidis',
#    '.'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O']),
#  (['--',
#    'Dimitris',
#    'Kontogiannis',
#    ',',
#    'Athens',
#    'Newsroom',
#    '+301',
#    '3311812-4'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['<unk>', 'sets', 'C$', '100', 'million', 'six-year', 'bond', '.'],
#   ['B-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O']),
#  (['LONDON', '1996-08-22'], ['B-LOC', 'O']),
#  (['The',
#    'following',
#    'bond',
#    'was',
#    'announced',
#    'by',
#    'lead',
#    'manager',
#    'Toronto',
#    'Dominion',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']),
#  (['BORROWER', 'BAYERISCHE', 'VEREINSBANK'], ['O', 'B-ORG', 'I-ORG']),
#  (['AMT', 'C$', '100', 'MLN', 'COUPON', '<unk>', 'MATURITY', '<unk>'],
#   ['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['TYPE', 'STRAIGHT', 'ISS', 'PRICE', '<unk>', 'PAY', 'DATE', '<unk>'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['FULL', 'FEES', '<unk>', 'REOFFER', '<unk>', 'SPREAD', '<unk>', 'BP'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['MOODY', '<unk>', 'LISTING', '<unk>', 'PAY', '<unk>', '='],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['S&P',
#    '=',
#    'DENOMS',
#    '(',
#    'K',
#    ')',
#    '1-10-100',
#    'SALE',
#    'LIMITS',
#    'US',
#    '/',
#    'UK',
#    '/',
#    '<unk>'],
#   ['B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC']),
#  (['NEG', 'PLG', 'NO', 'CRS', 'DEFLT', 'NO', 'FORCE', 'MAJ', '='],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['GOV', 'LAW', 'GERMAN', 'HOME', 'CTRY', '=', 'TAX', 'PROVS', 'STANDARD'],
#   ['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['MGT', '/', 'UND', '<unk>', 'SELL', 'CONC', '<unk>', 'PRAECIP', '='],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['<unk>', 'GOVT', 'BOND', '7.0', 'PCT', '<unk>', '2001'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['NOTES', 'BAYERISCHE', 'VEREINSBANK', 'IS', '<unk>', 'LEAD', 'MANAGER'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O']),
#  (['--', 'London', 'Newsroom', '+44', '171', '542', '7658'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['<unk>', 'sets', '$', '300', 'million', 'January', '1999', 'FRN', '.'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['LONDON', '1996-08-22'], ['B-LOC', 'O']),
#  (['The',
#    'following',
#    '<unk>',
#    'issue',
#    'was',
#    'announced',
#    'by',
#    'lead',
#    'manager',
#    'Lehman',
#    'Brothers',
#    'International',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O']),
#  (['BORROWER',
#    '<unk>',
#    'AB',
#    '(',
#    'SWEDISH',
#    'NATIONAL',
#    '<unk>',
#    '<unk>',
#    ')'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'O']),
#  (['AMT', '$', '300', 'MLN', 'SPREAD', '-', '12.5', 'BP', 'MATURITY', '<unk>'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['TYPE', 'FRN', '<unk>', '<unk>', 'LIBOR', 'PAY', 'DATE', '<unk>'],
#   ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']),
#  (['LAST',
#    'MOODY',
#    '<unk>',
#    'ISS',
#    'PRICE',
#    '<unk>',
#    'FULL',
#    'FEES',
#    '10',
#    'BP'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['LAST', 'S&P', 'AA+', 'REOFFER', '='], ['O', 'B-ORG', 'O', 'O', 'O']),
#  (['NOTES', 'S', 'SHORT', 'FIRST', 'COUPON'], ['O', 'O', 'O', 'O', 'O']),
#  (['LISTING',
#    'LONDON',
#    'DENOMS',
#    '(',
#    'K',
#    ')',
#    '1-10-100',
#    'SALE',
#    'LIMITS',
#    'US',
#    '/',
#    'UK',
#    '/',
#    '<unk>',
#    '/',
#    '<unk>'],
#   ['O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC']),
#  (['NEG', 'PLG', '<unk>', 'CRS', 'DEFLT', 'NO', 'FORCE', 'MAJ', '<unk>', '2'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['GOV',
#    'LAW',
#    'ENGLISH',
#    'HOME',
#    'CTRY',
#    '<unk>',
#    'TAX',
#    'PROVS',
#    'STANDARD'],
#   ['O', 'O', 'B-MISC', 'O', 'O', 'B-LOC', 'O', 'O', 'O']),
#  (['MGT', '/', 'UND', '5', 'BP', 'SELL', 'CONC', '5', 'BP', 'PRAECIP', '='],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['NOTES', '<unk>', 'OFF', '<unk>', '<unk>'], ['O', 'O', 'O', 'O', 'O']),
#  (['--', 'London', 'Newsroom', '+44', '171', '542', '<unk>'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['Port',
#    'conditions',
#    'update',
#    '-',
#    'Syria',
#    '-',
#    'Lloyds',
#    'Shipping',
#    '.'],
#   ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-ORG', 'I-ORG', 'O']),
#  (['Port',
#    'conditions',
#    'from',
#    'Lloyds',
#    'Shipping',
#    'Intelligence',
#    'Service',
#    '--'],
#   ['O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O']),
#  (['<unk>',
#    ',',
#    'Aug',
#    '10',
#    '-',
#    'waiting',
#    'time',
#    'at',
#    '<unk>',
#    'and',
#    '<unk>',
#    '<unk>',
#    '24',
#    'hours',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['Israel', 'plays', 'down', 'fears', 'of', 'war', 'with', 'Syria', '.'],
#   ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']),
#  (['<unk>', '<unk>'], ['B-PER', 'I-PER']),
#  (['JERUSALEM', '1996-08-22'], ['B-LOC', 'O']),
#  (['Israel',
#    "'s",
#    'outgoing',
#    'peace',
#    'negotiator',
#    'with',
#    'Syria',
#    'said',
#    'on',
#    'Thursday',
#    'current',
#    'tensions',
#    'between',
#    'the',
#    'two',
#    'countries',
#    'appeared',
#    'to',
#    'be',
#    'a',
#    'storm',
#    'in',
#    'a',
#    'teacup',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Itamar',
#    'Rabinovich',
#    ',',
#    'who',
#    'as',
#    'Israel',
#    "'s",
#    'ambassador',
#    'to',
#    'Washington',
#    'conducted',
#    '<unk>',
#    'negotiations',
#    'with',
#    'Syria',
#    ',',
#    'told',
#    'Israel',
#    'Radio',
#    'it',
#    'looked',
#    'like',
#    'Damascus',
#    'wanted',
#    'to',
#    'talk',
#    'rather',
#    'than',
#    'fight',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['"',
#    'It',
#    'appears',
#    'to',
#    'me',
#    'the',
#    'Syrian',
#    'priority',
#    'is',
#    'still',
#    'to',
#    'negotiate',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['The',
#    'Syrians',
#    'are',
#    'confused',
#    ',',
#    'they',
#    'are',
#    'definitely',
#    'tense',
#    ',',
#    'but',
#    'the',
#    'general',
#    'assessment',
#    'here',
#    'in',
#    'Washington',
#    'is',
#    'that',
#    'this',
#    'is',
#    '<unk>',
#    'a',
#    'storm',
#    'in',
#    'a',
#    'teacup',
#    ',',
#    '"',
#    'he',
#    'said',
#    '.'],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Rabinovich',
#    'is',
#    'winding',
#    'up',
#    'his',
#    'term',
#    'as',
#    'ambassador',
#    '.'],
#   ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['He',
#    'will',
#    'be',
#    'replaced',
#    'by',
#    '<unk>',
#    '<unk>',
#    ',',
#    'a',
#    'former',
#    'Israeli',
#    'envoy',
#    'to',
#    'Egypt',
#    'and',
#    'right-wing',
#    'Likud',
#    'party',
#    'politician',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O']),
#  (['Israel',
#    'on',
#    'Wednesday',
#    'sent',
#    'Syria',
#    'a',
#    'message',
#    ',',
#    'via',
#    'Washington',
#    ',',
#    'saying',
#    'it',
#    'was',
#    'committed',
#    'to',
#    'peace',
#    'and',
#    'wanted',
#    'to',
#    'open',
#    'negotiations',
#    'without',
#    'preconditions',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['But',
#    'it',
#    'slammed',
#    'Damascus',
#    'for',
#    'creating',
#    'what',
#    'it',
#    'called',
#    'a',
#    'dangerous',
#    'atmosphere',
#    '.'],
#   ['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Syria',
#    'accused',
#    'Israel',
#    'on',
#    'Wednesday',
#    'of',
#    'launching',
#    'a',
#    '<unk>',
#    'campaign',
#    'against',
#    'it',
#    'after',
#    'Israeli',
#    'television',
#    'reported',
#    'that',
#    'Damascus',
#    'had',
#    'recently',
#    'test',
#    'fired',
#    'a',
#    'missile',
#    '.'],
#   ['B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['It',
#    'said',
#    'its',
#    'arms',
#    'purchases',
#    'were',
#    'for',
#    'defensive',
#    'purposes',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['"',
#    'The',
#    'message',
#    'that',
#    'we',
#    'sent',
#    'to',
#    '(',
#    'Syrian',
#    'President',
#    '<unk>',
#    '<unk>',
#    ')',
#    '<unk>',
#    'is',
#    'that',
#    'Israel',
#    'is',
#    'ready',
#    'at',
#    'any',
#    'time',
#    'without',
#    'preconditions',
#    'to',
#    'enter',
#    'peace',
#    'negotiations',
#    ',',
#    '"',
#    'Israeli',
#    'Foreign',
#    'Minister',
#    'David',
#    'Levy',
#    'told',
#    'Israel',
#    'Radio',
#    'in',
#    'an',
#    'interview',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Tension',
#    'has',
#    'mounted',
#    'since',
#    'Israeli',
#    'Prime',
#    'Minister',
#    'Benjamin',
#    'Netanyahu',
#    'took',
#    'office',
#    'in',
#    'June',
#    '<unk>',
#    'to',
#    'retain',
#    'the',
#    'Golan',
#    '<unk>',
#    'Israel',
#    'captured',
#    'from',
#    'Syria',
#    'in',
#    'the',
#    '1967',
#    'Middle',
#    'East',
#    'war',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'B-LOC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O']),
#  (['<unk>',
#    'peace',
#    'talks',
#    'have',
#    'been',
#    'deadlocked',
#    'over',
#    'the',
#    'Golan',
#    'since',
#    '1991',
#    'despite',
#    'the',
#    'previous',
#    'government',
#    "'s",
#    '<unk>',
#    'to',
#    'make',
#    'Golan',
#    'concessions',
#    '.'],
#   ['B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O']),
#  (['Peace',
#    'talks',
#    'between',
#    'the',
#    'two',
#    'sides',
#    'were',
#    'last',
#    'held',
#    'in',
#    'February',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['"',
#    'The',
#    'voices',
#    'coming',
#    'out',
#    'of',
#    'Damascus',
#    'are',
#    'bad',
#    ',',
#    'not',
#    'good',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['The', 'media', '...'], ['O', 'O', 'O']),
#  (['are',
#    'full',
#    'of',
#    '<unk>',
#    'and',
#    '<unk>',
#    'that',
#    'must',
#    'be',
#    'worrying',
#    '...'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['this',
#    '<unk>',
#    'atmosphere',
#    'is',
#    'very',
#    'dangerous',
#    'because',
#    'those',
#    'who',
#    'spread',
#    'it',
#    'could',
#    'become',
#    'its',
#    'prisoners',
#    ',',
#    '"',
#    'Levy',
#    'said',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O']),
#  (['"',
#    'We',
#    'expect',
#    'from',
#    'Syria',
#    ',',
#    'if',
#    'its',
#    'face',
#    'is',
#    'to',
#    'peace',
#    ',',
#    'that',
#    'it',
#    'will',
#    'answer',
#    'Israel',
#    "'s",
#    'message',
#    'to',
#    'enter',
#    'peace',
#    'negotiations',
#    'because',
#    'that',
#    'is',
#    'our',
#    'goal',
#    ',',
#    '"',
#    'he',
#    'said',
#    '.',
#    '"'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['We', 'do', 'not', 'want', 'a', 'war', ',', 'God', '<unk>', '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O']),
#  (['No', 'one', 'benefits', 'from', 'wars', '.', '"'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Israel',
#    "'s",
#    'Channel',
#    'Two',
#    'television',
#    'said',
#    'Damascus',
#    'had',
#    'sent',
#    'a',
#    '"',
#    '<unk>',
#    'signal',
#    '"',
#    'to',
#    'Israel',
#    '.'],
#   ['B-LOC',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']),
#  (['It', 'gave', 'no', 'source', 'for', 'the', 'report', '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Netanyahu',
#    'and',
#    'Levy',
#    "'s",
#    'spokesmen',
#    'said',
#    'they',
#    'could',
#    'not',
#    'confirm',
#    'it',
#    '.'],
#   ['B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['The',
#    'television',
#    'also',
#    'said',
#    'that',
#    'Netanyahu',
#    'had',
#    'sent',
#    'messages',
#    'to',
#    '<unk>',
#    'Syria',
#    'via',
#    'Cairo',
#    ',',
#    'the',
#    'United',
#    'States',
#    'and',
#    'Moscow',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'B-LOC',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['Polish', 'diplomat', 'denies', 'nurses', 'stranded', 'in', 'Libya', '.'],
#   ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']),
#  (['TUNIS', '1996-08-22'], ['B-LOC', 'O']),
#  (['A',
#    'Polish',
#    'diplomat',
#    'on',
#    'Thursday',
#    'denied',
#    'a',
#    'Polish',
#    'tabloid',
#    'report',
#    'this',
#    'week',
#    'that',
#    'Libya',
#    'was',
#    'refusing',
#    'exit',
#    'visas',
#    'to',
#    '100',
#    'Polish',
#    'nurses',
#    'trying',
#    'to',
#    'return',
#    'home',
#    'after',
#    'working',
#    'in',
#    'the',
#    'North',
#    'African',
#    'country',
#    '.'],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O']),
#  (['"', 'This', 'is', 'not', 'true', '.'], ['O', 'O', 'O', 'O', 'O', 'O']),
#  (['Up',
#    'to',
#    'today',
#    ',',
#    'we',
#    'have',
#    'no',
#    'knowledge',
#    'of',
#    'any',
#    'nurse',
#    'stranded',
#    'or',
#    'kept',
#    'in',
#    'Libya',
#    'without',
#    'her',
#    'will',
#    ',',
#    'and',
#    'we',
#    'have',
#    'not',
#    'received',
#    'any',
#    'complaint',
#    ',',
#    '"',
#    'the',
#    'Polish',
#    'embassy',
#    "'s",
#    'charge',
#    '<unk>',
#    'in',
#    'Tripoli',
#    ',',
#    '<unk>',
#    'Awdankiewicz',
#    ',',
#    'told',
#    'Reuters',
#    'by',
#    'telephone',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O']),
#  (['Poland',
#    "'s",
#    'labour',
#    'ministry',
#    'said',
#    'this',
#    'week',
#    'it',
#    'would',
#    'send',
#    'a',
#    'team',
#    'to',
#    'Libya',
#    'to',
#    'investigate',
#    ',',
#    'but',
#    'Awdankiewicz',
#    'said',
#    'the',
#    'probe',
#    'was',
#    'prompted',
#    'by',
#    'some',
#    'nurses',
#    'complaining',
#    'about',
#    'their',
#    'work',
#    'conditions',
#    'such',
#    'as',
#    '<unk>',
#    'of',
#    'their',
#    'salaries',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['He',
#    'said',
#    'that',
#    'there',
#    'are',
#    'an',
#    'estimated',
#    '800',
#    'Polish',
#    'nurses',
#    'working',
#    'in',
#    'Libya',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['Two', 'Iranian', 'opposition', 'leaders', 'meet', 'in', 'Baghdad', '.'],
#   ['O', 'B-MISC', 'O', 'O', 'O', 'O', 'B-LOC', 'O']),
#  (['Hassan', '<unk>'], ['B-PER', 'I-PER']),
#  (['BAGHDAD', '1996-08-22'], ['B-LOC', 'O']),
#  (['An',
#    'Iranian',
#    'exile',
#    'group',
#    'based',
#    'in',
#    'Iraq',
#    'vowed',
#    'on',
#    'Thursday',
#    'to',
#    'extend',
#    'support',
#    'to',
#    'Iran',
#    "'s",
#    'Kurdish',
#    'rebels',
#    'after',
#    'they',
#    'were',
#    'attacked',
#    'by',
#    'Iranian',
#    'troops',
#    'deep',
#    'inside',
#    'Iraq',
#    'last',
#    'month',
#    '.'],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O']),
#  (['A',
#    'Mujahideen',
#    'Khalq',
#    'statement',
#    'said',
#    'its',
#    'leader',
#    'Massoud',
#    'Rajavi',
#    'met',
#    'in',
#    'Baghdad',
#    'the',
#    'Secretary-General',
#    'of',
#    'the',
#    'Kurdistan',
#    'Democratic',
#    'Party',
#    'of',
#    'Iran',
#    '(',
#    'KDPI',
#    ')',
#    'Hassan',
#    '<unk>',
#    'on',
#    'Wednesday',
#    'and',
#    'voiced',
#    'his',
#    'support',
#    'to',
#    'Iran',
#    "'s",
#    'rebel',
#    'Kurds',
#    '.'],
#   ['O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-MISC',
#    'O']),
#  (['"',
#    'Rajavi',
#    '<unk>',
#    'that',
#    'the',
#    'Iranian',
#    '<unk>',
#    'would',
#    'continue',
#    'to',
#    'stand',
#    'side',
#    'by',
#    'side',
#    'with',
#    'their',
#    'Kurdish',
#    '<unk>',
#    'and',
#    'the',
#    'resistance',
#    'movement',
#    'in',
#    'Iranian',
#    'Kurdistan',
#    ',',
#    '"',
#    'it',
#    'said',
#    '.'],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['A',
#    'spokesman',
#    'for',
#    'the',
#    'group',
#    'said',
#    'the',
#    'meeting',
#    '"',
#    'signals',
#    'a',
#    'new',
#    'level',
#    'of',
#    'cooperation',
#    'between',
#    'Mujahideen',
#    'Khalq',
#    'and',
#    'the',
#    'Iranian',
#    'Kurdish',
#    '<unk>',
#    '"',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O']),
#  (['Iran',
#    'heavily',
#    'bombarded',
#    'targets',
#    'in',
#    'northern',
#    'Iraq',
#    'in',
#    'July',
#    'in',
#    'pursuit',
#    'of',
#    'KDPI',
#    'guerrillas',
#    'based',
#    'in',
#    'Iraqi',
#    'Kurdish',
#    'areas',
#    'outside',
#    'the',
#    'control',
#    'of',
#    'the',
#    'government',
#    'in',
#    'Baghdad',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']),
#  (['Iraqi',
#    'Kurdish',
#    'areas',
#    'bordering',
#    'Iran',
#    'are',
#    'under',
#    'the',
#    'control',
#    'of',
#    'guerrillas',
#    'of',
#    'the',
#    'Iraqi',
#    'Kurdish',
#    'Patriotic',
#    'Union',
#    'of',
#    'Kurdistan',
#    '(',
#    'PUK',
#    ')',
#    'group',
#    '.'],
#   ['B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O']),
#  (['PUK',
#    'and',
#    'Iraq',
#    "'s",
#    'Kurdistan',
#    'Democratic',
#    'Party',
#    '(',
#    'KDP',
#    ')',
#    'the',
#    'two',
#    'main',
#    'Iraqi',
#    'Kurdish',
#    'factions',
#    ',',
#    'have',
#    'had',
#    'northern',
#    'Iraq',
#    'under',
#    'their',
#    'control',
#    'since',
#    'Iraqi',
#    'forces',
#    'were',
#    'ousted',
#    'from',
#    'Kuwait',
#    'in',
#    'the',
#    '1991',
#    'Gulf',
#    'War',
#    '.'],
#   ['B-ORG',
#    'O',
#    'B-LOC',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O']),
#  (['<unk>',
#    'between',
#    'the',
#    'two',
#    'parties',
#    'broke',
#    'out',
#    'at',
#    'the',
#    'weekend',
#    'in',
#    'the',
#    'most',
#    'serious',
#    'fighting',
#    'since',
#    'a',
#    '<unk>',
#    'ceasefire',
#    'last',
#    'year',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Mujahideen',
#    'Khalq',
#    'said',
#    'Iranian',
#    'troops',
#    'had',
#    'also',
#    'been',
#    'shelling',
#    'KDP',
#    'positions',
#    'in',
#    '<unk>',
#    'region',
#    'in',
#    '<unk>',
#    'province',
#    'near',
#    'the',
#    'Iranian',
#    'border',
#    'over',
#    'the',
#    'last',
#    'two',
#    'days',
#    '.'],
#   ['B-ORG',
#    'I-ORG',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['It',
#    'said',
# ...
#    'Milwaukee',
#    'Brewers',
#    'to',
#    'a',
#    '10-7',
#    'victory',
#    'over',
#    'the',
#    'Twins',
#    '.'],
#   ['O',
#    'B-LOC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O']),
#  (['Jaha',
#    'added',
#    'an',
#    'RBI',
#    'single',
#    'in',
#    'the',
#    'ninth',
#    'and',
#    'had',
#    'four',
#    'RBI',
#    '.'],
#   ['B-PER',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O']),
#  (['Jose', 'Valentin', 'hit', 'his', '21st', 'homer', 'for', 'Milwaukee', '.'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['SOCCER', '-', '<unk>', 'DOUBLE', '<unk>', 'PSV', '4-1', 'WIN', '.'],
#   ['O', 'O', 'B-PER', 'O', 'O', 'B-ORG', 'O', 'O', 'O']),
#  (['AMSTERDAM', '1996-08-22'], ['B-LOC', 'O']),
#  (['Philip',
#    'Cocu',
#    'scored',
#    'twice',
#    'in',
#    'the',
#    'second',
#    'half',
#    'to',
#    '<unk>',
#    'PSV',
#    'Eindhoven',
#    'to',
#    'a',
#    '4-1',
#    'away',
#    'win',
#    'over',
#    'NEC',
#    'Nijmegen',
#    'in',
#    'the',
#    'Dutch',
#    'first',
#    'division',
#    'on',
#    'Thursday',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['He',
#    'scored',
#    'from',
#    'close',
#    'range',
#    'in',
#    'the',
#    '54th',
#    'minute',
#    'and',
#    'from',
#    'a',
#    '<unk>',
#    'kick',
#    '13',
#    'minutes',
#    'later',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Arthur',
#    'Numan',
#    'and',
#    'Luc',
#    'Nilis',
#    ',',
#    'Dutch',
#    'top',
#    'scorer',
#    'last',
#    'season',
#    ',',
#    'were',
#    'PSV',
#    "'s",
#    'other',
#    '<unk>',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Ajax',
#    'Amsterdam',
#    'opened',
#    'their',
#    'title',
#    'defence',
#    'with',
#    'a',
#    '1-0',
#    'win',
#    'over',
#    'NAC',
#    'Breda',
#    'on',
#    'Wednesday',
#    '.'],
#   ['B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['SOCCER', '-', 'DUTCH', 'FIRST', 'DIVISION', 'SUMMARY', '.'],
#   ['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O']),
#  (['AMSTERDAM', '1996-08-22'], ['B-LOC', 'O']),
#  (['Summary', 'of', 'Thursday', "'s", 'only'], ['O', 'O', 'O', 'O', 'O']),
#  (['Dutch', 'first', 'division', 'match', ':'],
#   ['B-MISC', 'O', 'O', 'O', 'O']),
#  (['NEC',
#    'Nijmegen',
#    '1',
#    '(',
#    'Van',
#    '<unk>',
#    '15th',
#    ')',
#    'PSV',
#    'Eindhoven',
#    '4',
#    '(',
#    'Numan',
#    '11th',
#    ','],
#   ['B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Nilis', '42nd', ',', 'Cocu', '54th', ',', '67th', ')', '.'],
#   ['B-PER', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O']),
#  (['Halftime', '1-2', '.'], ['O', 'O', 'O']),
#  (['Attendance', '8,000'], ['O', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['SOCCER', '-', 'DUTCH', 'FIRST', 'DIVISION', 'RESULT', '.'],
#   ['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O']),
#  (['AMSTERDAM', '1996-08-22'], ['B-LOC', 'O']),
#  (['Result', 'of', 'a', 'Dutch', 'first'], ['O', 'O', 'O', 'B-MISC', 'O']),
#  (['division', 'match', 'on', 'Thursday', ':'], ['O', 'O', 'O', 'O', 'O']),
#  (['NEC', 'Nijmegen', '1', 'PSV', 'Eindhoven', '4'],
#   ['B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG', 'O']),
#  (['-DOCSTART-'], ['O']),
#  (['SOCCER', '-', '<unk>', '<unk>', 'BACK', 'IN', 'SWISS', 'SQUAD', '.'],
#   ['O', 'O', 'O', 'B-PER', 'O', 'O', 'B-MISC', 'O', 'O']),
#  (['GENEVA', '1996-08-22'], ['B-LOC', 'O']),
#  (['Galatasaray',
#    'striker',
#    'Adrian',
#    'Knup',
#    ',',
#    'scorer',
#    'of',
#    '26',
#    'goals',
#    'in',
#    '45',
#    'internationals',
#    ',',
#    'has',
#    'been',
#    'recalled',
#    'by',
#    'Switzerland',
#    'for',
#    'the',
#    'World',
#    'Cup',
#    'qualifier',
#    'against',
#    'Azerbaijan',
#    'in',
#    '<unk>',
#    'on',
#    'August',
#    '31',
#    '.'],
#   ['B-ORG',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Knup',
#    'was',
#    'overlooked',
#    'by',
#    'Artur',
#    'Jorge',
#    'for',
#    'the',
#    'European',
#    'championship',
#    'finals',
#    'earlier',
#    'this',
#    'year',
#    '.'],
#   ['B-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['But',
#    'new',
#    'coach',
#    'Rolf',
#    '<unk>',
#    'is',
#    'clearly',
#    'a',
#    'Knup',
#    'fan',
#    'and',
#    'included',
#    'him',
#    'in',
#    'his',
#    '<unk>',
#    'squad',
#    'on',
#    'Thursday',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['Switzerland',
#    'failed',
#    'to',
#    'progress',
#    'beyond',
#    'the',
#    'opening',
#    'group',
#    'phase',
#    'in',
#    'Euro',
#    '96',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O']),
#  (['Squad', ':'], ['O', 'O']),
#  (['Goalkeepers',
#    '-',
#    'Marco',
#    '<unk>',
#    '(',
#    'Cagliari',
#    ')',
#    ',',
#    'Pascal',
#    '<unk>',
#    '(',
#    'Grasshoppers',
#    ')',
#    '.'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O']),
#  (['Defenders',
#    '-',
#    'Stephane',
#    '<unk>',
#    '(',
#    'Hamburg',
#    ')',
#    ',',
#    'Marc',
#    '<unk>',
#    '(',
#    'Everton',
#    ')',
#    ',',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Sion',
#    ')',
#    ',',
#    'Ramon',
#    'Vega',
#    '(',
#    'Cagliari',
#    ')',
#    'Raphael',
#    '<unk>',
#    '(',
#    'Sion',
#    ')',
#    '.'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O']),
#  (['Midfielders',
#    '-',
#    'Alexandre',
#    '<unk>',
#    '(',
#    'Grasshoppers',
#    ')',
#    ',',
#    'Antonio',
#    '<unk>',
#    '(',
#    'Grasshoppers',
#    ')',
#    ',',
#    'Sebastien',
#    '<unk>',
#    '(',
#    'Stuttgart',
#    ')',
#    ',',
#    'Christophe',
#    '<unk>',
#    '(',
#    'Lausanne',
#    ')',
#    ',',
#    'Patrick',
#    '<unk>',
#    '(',
#    'Sion',
#    ')',
#    ',',
#    'David',
#    '<unk>',
#    '(',
#    'Servette',
#    ')',
#    ',',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Inter',
#    'Milan',
#    ')',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Grasshoppers',
#    ')',
#    '.'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O']),
#  (['Strikers',
#    '-',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Grasshoppers',
#    ')',
#    ',',
#    'Adrian',
#    'Knup',
#    '(',
#    'Galatasaray',
#    ')',
#    ',',
#    'Christophe',
#    '<unk>',
#    '(',
#    'Sion',
#    ')',
#    ',',
#    'Stephane',
#    '<unk>',
#    '(',
#    'Borussia',
#    'Dortmund',
#    ')',
#    '.'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['ATHLETICS',
#    '-',
#    'IT',
#    "'S",
#    'A',
#    'RECORD',
#    '-',
#    '40,000',
#    '<unk>',
#    'ON',
#    'THE',
#    '<unk>',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['BRUSSELS', '1996-08-22'], ['B-LOC', 'O']),
#  (['<unk>',
#    'at',
#    'Friday',
#    "'s",
#    'Brussels',
#    'grand',
#    'prix',
#    'meeting',
#    'have',
#    'an',
#    'extra',
#    '<unk>',
#    'to',
#    '<unk>',
#    'on',
#    'the',
#    'athletes',
#    'to',
#    'world',
#    'record',
#    'performances',
#    '--',
#    'a',
#    'free',
#    'glass',
#    'of',
#    'beer',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['A',
#    'Belgian',
#    '<unk>',
#    'has',
#    'offered',
#    'to',
#    'pay',
#    'for',
#    'a',
#    'free',
#    'round',
#    'of',
#    'drinks',
#    'for',
#    'all',
#    'of',
#    'the',
#    '40,000',
#    'crowd',
#    'if',
#    'a',
#    'world',
#    'record',
#    'goes',
#    'at',
#    'the',
#    'meeting',
#    ',',
#    'organisers',
#    'said',
#    'on',
#    'Thursday',
#    '.'],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['It',
#    'could',
#    'be',
#    'one',
#    'of',
#    'the',
#    'most',
#    'expensive',
#    'rounds',
#    'of',
#    'drinks',
#    'ever',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['The', 'meeting', 'is', 'sold', 'out', 'already', '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (['Two',
#    'world',
#    'records',
#    'are',
#    'in',
#    'serious',
#    'danger',
#    'of',
#    'being',
#    'broken',
#    'at',
#    'the',
#    'meeting',
#    '--',
#    'the',
#    'women',
#    "'s",
#    '1,000',
#    'metres',
#    'and',
#    'the',
#    'men',
#    "'s",
#    '3,000',
#    'metres',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (['-DOCSTART-'], ['O']),
#  (['GOLF', '-', 'GERMAN', 'OPEN', 'FIRST', 'ROUND', 'SCORES', '.'],
#   ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O']),
#  (['STUTTGART', ',', 'Germany', '1996-08-22'], ['B-LOC', 'O', 'B-LOC', 'O']),
#  (['Leading', 'first', 'round'], ['O', 'O', 'O']),
#  (['scores',
#    'in',
#    'the',
#    'German',
#    'Open',
#    'golf',
#    'championship',
#    'on',
#    'Thursday',
#    '(',
#    'Britain'],
#   ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'B-LOC']),
#  (['unless', 'stated', ')', ':'], ['O', 'O', 'O', 'O']),
#  (['62', 'Paul', 'Broadhurst'], ['O', 'B-PER', 'I-PER']),
#  (['63', 'Raymond', 'Russell'], ['O', 'B-PER', 'I-PER']),
#  (['64',
#    'David',
#    'J.',
#    'Russell',
#    ',',
#    'Michael',
#    'Campbell',
#    '(',
#    'New',
#    'Zealand',
#    ')',
#    ',',
#    'Ian'],
#   ['O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'B-PER']),
#  (['Woosnam',
#    ',',
#    'Bernhard',
#    'Langer',
#    '(',
#    'Germany',
#    ')',
#    ',',
#    'Ronan',
#    'Rafferty',
#    ',',
#    'Mats'],
#   ['B-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER']),
#  (['Lanner', '(', 'Sweden', ')', ',', 'Wayne', 'Riley', '(', 'Australia', ')'],
#   ['B-PER', 'O', 'B-LOC', 'O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O']),
#  (['65',
#    'Eamonn',
#    'Darcy',
#    '(',
#    'Ireland',
#    ')',
#    ',',
#    'Per',
#    '<unk>',
#    '(',
#    'Sweden',
#    ')',
#    ',',
#    'Russell',
#    'Claydon',
#    ','],
#   ['O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O']),
#  (['Mark',
#    'Roe',
#    ',',
#    'Retief',
#    'Goosen',
#    '(',
#    'South',
#    'Africa',
#    ')',
#    ',',
#    'Carl',
#    'Suneson'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER']),
#  (['66',
#    'Stephen',
#    'Field',
#    ',',
#    'Paul',
#    'Lawrie',
#    ',',
#    'Ian',
#    'Pyman',
#    ',',
#    'Max',
#    '<unk>'],
#   ['O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER']),
#  (['(',
#    'Sweden',
#    ')',
#    ',',
#    'Miles',
#    '<unk>',
#    ',',
#    'Christian',
#    'Cevaer',
#    '(',
#    'France',
#    ')',
#    ','],
#   ['O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O']),
#  (['Des',
#    'Smyth',
#    '(',
#    'Ireland',
#    ')',
#    ',',
#    'David',
#    'Carter',
#    ',',
#    'Lee',
#    'Westwood',
#    ',',
#    'Greg'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER']),
#  (['<unk>',
#    '(',
#    'Australia',
#    ')',
#    ',',
#    'Miguel',
#    'Angel',
#    'Martin',
#    '(',
#    'Spain',
#    ')',
#    ','],
#   ['B-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O']),
#  (['Thomas',
#    'Bjorn',
#    '(',
#    'Denmark',
#    ')',
#    ',',
#    'Fernando',
#    'Roca',
#    '(',
#    'Spain',
#    ')',
#    ',',
#    'Derrick'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER']),
#  (['<unk>'], ['B-PER']),
#  (['67',
#    'Jeff',
#    'Hawksworth',
#    ',',
#    'Padraig',
#    'Harrington',
#    '(',
#    'Ireland',
#    ')',
#    ',',
#    'Michael'],
#   ['O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER']),
#  (['<unk>',
#    ',',
#    'Thomas',
#    'Gogele',
#    '(',
#    'Germany',
#    ')',
#    ',',
#    'Paul',
#    'McGinley',
#    '(',
#    'Ireland',
#    ')',
#    ','],
#   ['B-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O']),
#  (['Gary',
#    'Orr',
#    ',',
#    '<unk>',
#    'Canizares',
#    '(',
#    'Spain',
#    ')',
#    ',',
#    'Michael',
#    'Jonzon'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER']),
#  (['(',
#    'Sweden',
#    ')',
#    ',',
#    'Paul',
#    'Eales',
#    ',',
#    'David',
#    'Williams',
#    ',',
#    'Andrew',
#    'Coltart',
#    ','],
#   ['O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O']),
#  (['Jonathan',
#    'Lomas',
#    ',',
#    'Jose',
#    '<unk>',
#    '(',
#    'Spain',
#    ')',
#    ',',
#    'Robert',
#    'Karlsson'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER']),
#  (['(',
#    'Sweden',
#    ')',
#    ',',
#    'Marcus',
#    '<unk>',
#    ',',
#    'Pedro',
#    'Linhart',
#    '(',
#    'Spain',
#    ')',
#    ',',
#    'Jamie'],
#   ['O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER']),
#  (['<unk>',
#    ',',
#    'Terry',
#    'Price',
#    '(',
#    'Australia',
#    ')',
#    ',',
#    'Juan',
#    'Carlos',
#    '<unk>',
#    '(',
#    'Spain',
#    ')',
#    ','],
#   ['B-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'B-LOC',
#    'O',
#    'O']),
#  (['Mark', '<unk>'], ['B-PER', 'I-PER']),
#  (['-DOCSTART-'], ['O']),
#  (['SOCCER',
#    '-',
#    'UEFA',
#    '<unk>',
#    'THREE',
#    '<unk>',
#    'FOR',
#    '<unk>',
#    'PLAY',
#    '.'],
#   ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  ...]

# %%
class BLSTM1(nn.Module):
    def __init__(self):
        super(BLSTM1, self).__init__()
        self.embedding = nn.Embedding(len(vocab), 100)
        self.blstm = nn.LSTM(input_size=100,hidden_size=256,bidirectional=True)
        self.dropout = nn.Dropout(0.33)
        self.hidden = nn.Linear(512,128)
        self.ELU = nn.ELU()
        self.output = nn.Linear(128,len(unique_tags))
    
    def forward(self,sentence):
        # pad sentence to equal length
        word_embedding = self.embedding(sentence)
        lstm_out, _ = self.blstm(word_embedding.view(len(sentence), 1, -1)) # input reshaped to sequence length, batch, input dim
        lstm_out = self.dropout(lstm_out)
        x = self.hidden(lstm_out.view(len(sentence), -1))
        x = self.ELU(x)
        x = self.output(x)
        return x

# %%
def blstm_train(model,loss_function,optimizer,scheduler,training_data,validation_data,num_epochs=20):
    for epoch in range(num_epochs):
        train_loss = 0
        for sentence,tags in tqdm.notebook.tqdm(training_data,total=len(training_data)):
            model.zero_grad()
            
            sentence_in = prepare_sequence(sentence,word_to_idx) #X
            targets = prepare_sequence(tags,tag_to_idx) #Y
            
            tag_scores = model(sentence_in) #Yhat
            
            loss = loss_function(tag_scores, targets)
            train_loss += loss
            loss.backward()
            optimizer.step()
            scheduler.step()
        
        train_loss /= len(training_data)
        val_loss = 0
        gold_tags = []
        pred_tags = []
        with torch.no_grad():
            for sentence,tags in validation_data:
                sentence_in = prepare_sequence(sentence,word_to_idx) #X
                targets = prepare_sequence(tags,tag_to_idx) #Y
                tag_scores = model(sentence_in) #Yhat
                gold_tags.append(tags)
                pred_tags.append([idx_to_tag[x] for x in torch.argmax(tag_scores,dim=1).tolist()])
                loss = loss_function(tag_scores, targets)
                
                val_loss += loss
        val_loss /= len(validation_data)
        val_f1 = f1_score(gold_tags,pred_tags)
        print('Epoch {}/{}:\ttrain_loss = {}\tval_loss = {}\tval_f1 = {}'.format(epoch+1,
                                                                    num_epochs,
                                                                    round(train_loss.item(),3),
                                                                    round(val_loss.item(),3),
                                                                    round(val_f1,3)))

# %%
model = BLSTM1()
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

blstm_train(model,loss_function,optimizer,scheduler,training_data,validation_data)
# Out:
#   0%|          | 0/14987 [00:00<?, ?it/s]
# Epoch 1/20:	train_loss = 2.137	val_loss = 2.137	val_f1 = 0.019
#   0%|          | 0/14987 [00:00<?, ?it/s]
# Epoch 2/20:	train_loss = 2.137	val_loss = 2.137	val_f1 = 0.019
#   0%|          | 0/14987 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-196-fc8030cccedc> in <module>
#       4 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
#       5
# ----> 6 blstm_train(model,loss_function,optimizer,scheduler,training_data,validation_data)
#
# <ipython-input-195-79253fe4e9ee> in blstm_train(model, loss_function, optimizer, scheduler, training_data, validation_data, num_epochs)
#      12             loss = loss_function(tag_scores, targets)
#      13             train_loss += loss
# ---> 14             loss.backward()
#      15             optimizer.step()
#      16             scheduler.step()
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145         retain_graph = create_graph
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
gold_tags = []
pred_tags = []
with torch.no_grad():
    for sentence,tags in validation_data:
        sentence_in = prepare_sequence(sentence,word_to_idx) #X
        targets = prepare_sequence(tags,tag_to_idx) #Y
        tag_scores = model(sentence_in) #Yhat
        gold_tags.append(tags)
        pred_tags.append([idx_to_tag[x] for x in torch.argmax(tag_scores,dim=1).tolist()])
val_f1 = f1_score(gold_tags,pred_tags)

# %%
pred_tags
# Out:
# [['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'O', 'I-ORG'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-MISC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O'],
#  ['I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'I-LOC'],
#  ['I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['I-PER',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-LOC', 'B-MISC', 'I-PER', 'O', 'O', 'O', 'O'],
#  ['I-PER'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'I-LOC'],
#  ['I-PER', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'I-ORG'],
#  ['O', 'O'],
#  ['O', 'I-PER', 'O', 'O', 'O', 'B-MISC'],
#  ['I-LOC', 'O', 'B-MISC', 'O', 'I-LOC', 'B-MISC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O'],
#  ['I-PER', 'O', 'O', 'I-LOC'],
#  ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O'],
#  ['O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['I-LOC', 'O', 'O'],
#  ['I-LOC'],
#  ['I-LOC', 'O', 'O', 'I-LOC', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'B-MISC', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'O', 'B-MISC', 'B-MISC', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'B-MISC', 'I-LOC', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['I-LOC'],
#  ['O', 'I-ORG', 'I-PER', 'B-MISC', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'I-LOC', 'O', 'O'],
#  ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-ORG', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'B-MISC', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'I-ORG', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC'],
#  ['I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'O'],
#  ['B-MISC',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'I-LOC'],
#  ['O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O'],
#  ['O', 'I-LOC', 'I-PER', 'O'],
#  ['O', 'B-MISC', 'O', 'O', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O'],
#  ['O', 'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC'],
#  ['I-PER', 'O', 'O', 'O', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-PER', 'O'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O'],
#  ['I-LOC',
#   'I-ORG',
#   'B-LOC',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'I-LOC', 'I-ORG'],
#  ['O', 'I-PER', 'B-MISC'],
#  ['O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-LOC', 'O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-PER', 'O', 'I-LOC'],
#  ['O', 'B-MISC', 'I-PER', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O'],
#  ['O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'B-MISC',
#   'I-PER',
#   'I-ORG'],
#  ['O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER'],
#  ['O',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O'],
#  ['B-MISC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'I-PER', 'I-LOC', 'O'],
#  ['O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['I-PER', 'O', 'O', 'I-ORG', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER'],
#  ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O'],
#  ['B-MISC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-PER'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-MISC', 'B-LOC', 'O', 'I-PER'],
#  ['O', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER'],
#  ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'I-LOC', 'I-PER', 'O', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'O', 'O', 'B-MISC'],
#  ['O', 'O', 'B-MISC', 'O', 'O', 'B-MISC', 'O'],
#  ['I-LOC'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O'],
#  ['B-MISC', 'O', 'I-LOC', 'O', 'B-MISC', 'I-LOC'],
#  ['I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC'],
#  ['I-PER', 'O', 'I-PER', 'O', 'O', 'I-LOC'],
#  ['I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O'],
#  ['O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['B-MISC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['I-PER', 'O', 'I-LOC', 'I-LOC', 'B-MISC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-PER'],
#  ['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-LOC', 'I-LOC', 'I-LOC', 'O', 'I-LOC', 'I-PER', 'B-MISC'],
#  ['O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-LOC'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'B-MISC'],
#  ['O', 'I-LOC', 'I-ORG', 'I-LOC', 'B-MISC', 'I-PER', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'I-PER', 'O'],
#  ['I-LOC', 'I-LOC'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['I-PER'],
#  ['I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-LOC', 'O', 'I-LOC'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER', 'I-PER'],
#  ['O', 'O'],
#  ['O', 'I-LOC', 'O', 'O'],
#  ['O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'B-MISC', 'I-LOC', 'O'],
#  ['I-PER', 'O', 'I-PER', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER', 'O'],
#  ['I-LOC', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'I-PER', 'I-PER', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'I-PER', 'O', 'B-MISC', 'O', 'O'],
#  ['I-LOC', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC'],
#  ['O', 'O', 'I-LOC', 'O', 'I-LOC', 'O'],
#  ['O', 'I-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-ORG', 'O'],
#  ['O', 'I-LOC', 'O', 'O'],
#  ['I-PER', 'O', 'I-LOC'],
#  ['O', 'I-PER', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'I-PER'],
#  ['O', 'I-LOC'],
#  ['B-LOC', 'I-LOC', 'O', 'I-ORG'],
#  ['B-MISC', 'I-PER', 'O', 'O', 'O'],
#  ['B-LOC', 'I-ORG', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'I-LOC', 'O', 'O', 'O', 'I-LOC'],
#  ['I-PER', 'O', 'I-PER', 'O', 'I-LOC'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'B-MISC', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-PER', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O'],
#  ['O', 'B-MISC', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'I-LOC'],
#  ['O', 'B-MISC', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'I-PER', 'B-MISC', 'I-LOC', 'O'],
#  ['B-MISC', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['B-MISC', 'B-MISC', 'O', 'O'],
#  ['O', 'I-PER', 'O', 'O'],
#  ['O', 'O', 'I-PER'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['I-PER'],
#  ['I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'I-ORG'],
#  ['I-LOC', 'O', 'I-LOC'],
#  ['B-MISC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'I-PER', 'I-LOC', 'O', 'O'],
#  ['I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-PER', 'O'],
#  ['O', 'I-PER', 'I-LOC', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'B-LOC', 'O'],
#  ['I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'B-MISC', 'I-PER'],
#  ['O', 'O', 'O', 'I-LOC', 'B-LOC'],
#  ['O', 'O', 'O', 'O', 'I-PER'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'I-ORG'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O', 'O', 'B-MISC', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'I-LOC', 'I-LOC'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-LOC',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'I-LOC'],
#  ['O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'B-MISC',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O'],
#  ['I-PER',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'B-MISC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-PER',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'O',
#   'I-LOC',
#   'I-PER'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-PER', 'I-ORG'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC'],
#  ['I-LOC',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'I-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'B-MISC',
#   'I-PER',
#   'I-LOC',
#   'I-PER'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'O', 'I-LOC', 'B-MISC', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-LOC'],
#  ['O', 'O', 'I-LOC', 'O', 'B-MISC', 'O'],
#  ['O', 'O', 'I-LOC', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'O'],
#  ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'B-MISC', 'O', 'O', 'I-PER', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'I-PER',
#   'I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['I-PER'],
#  ['O', 'I-PER', 'I-MISC', 'I-ORG', 'I-ORG', 'I-LOC'],
#  ['O', 'I-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'I-LOC', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-PER'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-ORG'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC'],
#  ['B-MISC', 'B-MISC', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'O'],
#  ['O',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'I-LOC', 'I-PER', 'O'],
#  ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'B-MISC', 'I-LOC', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-MISC'],
#  ['O', 'I-LOC', 'O', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'I-PER',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-PER'],
#  ['O',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O'],
#  ['I-LOC', 'B-MISC', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'I-PER', 'I-LOC', 'I-PER'],
#  ['O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC'],
#  ['I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O'],
#  ['O',
#   'B-MISC',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC'],
#  ['I-LOC', 'O'],
#  ['O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'I-LOC'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC'],
#  ['I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'B-MISC', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O'],
#  ['B-MISC', 'I-LOC'],
#  ['O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-LOC'],
#  ['I-PER', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-LOC'],
#  ['O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O'],
#  ['I-PER', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'I-PER', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'I-LOC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'I-PER'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['I-PER', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'I-PER', 'B-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'I-LOC', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'I-LOC'],
#  ['O', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-ORG'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['I-PER', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O', 'O'],
#  ['I-PER', 'O', 'O', 'I-LOC', 'B-MISC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'O', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'I-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-PER', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC'],
#  ['I-PER', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'I-ORG', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER', 'O'],
#  ['O', 'I-PER', 'O', 'O', 'O', 'O', 'I-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC'],
#  ['O', 'I-LOC', 'O', 'O', 'I-LOC', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'B-MISC', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'I-LOC', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'B-MISC', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'O', 'I-PER', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['I-PER', 'O', 'O', 'B-MISC'],
#  ['I-LOC', 'O', 'O', 'O', 'I-PER', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'I-PER', 'O', 'O'],
#  ['I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-MISC', 'B-MISC', 'B-MISC'],
#  ['I-LOC', 'O', 'O', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O'],
#  ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'I-LOC', 'I-PER', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'I-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-PER', 'O', 'O'],
#  ['O', 'O', 'I-ORG', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'O', 'I-LOC', 'O', 'O'],
#  ['B-MISC', 'O', 'B-MISC', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-ORG', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'B-MISC'],
#  ['I-PER', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC'],
#  ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'B-MISC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'B-MISC', 'O', 'O', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['I-PER', 'O', 'I-PER', 'I-LOC'],
#  ['I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'I-LOC', 'I-LOC'],
#  ['O', 'I-ORG', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O', 'O'],
#  ['I-LOC', 'O', 'O', 'I-LOC', 'I-PER', 'I-LOC', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'I-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'I-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['I-PER', 'O', 'O', 'B-MISC', 'I-PER', 'O', 'O'],
#  ['I-ORG', 'O', 'B-MISC', 'O', 'I-PER', 'B-MISC', 'O', 'B-MISC'],
#  ['I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'B-MISC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-LOC', 'O'],
#  ['O', 'O'],
#  ['I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O'],
#  ['I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'B-MISC',
#   'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'I-LOC'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'I-PER',
#   'I-ORG',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
# ...
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O',
#   'I-LOC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'B-MISC',
#   'O'],
#  ['O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-LOC'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'I-LOC'],
#  ['I-PER', 'I-LOC'],
#  ['I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER'],
#  ['O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O'],
#  ['O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-ORG',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER'],
#  ['O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-ORG'],
#  ['O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'I-ORG',
#   'I-PER'],
#  ['O', 'O', 'I-ORG', 'O', 'I-ORG', 'I-LOC', 'O', 'O', 'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'I-LOC'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-ORG',
#   'I-ORG'],
#  ['I-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER'],
#  ['O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-LOC',
#   'I-ORG',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O'],
#  ['O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG'],
#  ['O'],
#  ['O', 'I-LOC', 'O', 'I-LOC', 'O', 'I-ORG', 'I-ORG'],
#  ['O', 'O'],
#  ['I-ORG', 'I-LOC', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-ORG',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['I-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-ORG',
#   'I-LOC'],
#  ['O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-MISC',
#   'I-LOC',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'I-PER',
#   'I-ORG',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'I-PER',
#   'B-LOC',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O'],
#  ['I-PER'],
#  ['I-PER', 'I-PER', 'I-PER', 'O', 'O', 'I-LOC', 'I-LOC'],
#  ['O', 'O'],
#  ['B-MISC',
#   'O',
#   'B-MISC',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'I-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['I-PER'],
#  ['O', 'O', 'I-PER', 'I-LOC', 'I-PER', 'O', 'O', 'O', 'O'],
#  ['I-LOC', 'O'],
#  ['O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-ORG'],
#  ['O', 'O', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'I-LOC', 'I-ORG'],
#  ['B-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-MISC',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC'],
#  ['I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O'],
#  ['I-LOC'],
#  ['I-LOC', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'I-LOC'],
#  ['O', 'I-LOC', 'O', 'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER'],
#  ['I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'I-LOC',
#   'B-MISC',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER'],
#  ['I-ORG', 'O', 'O', 'B-MISC', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'O'],
#  ['I-PER'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'I-LOC'],
#  ['O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O'],
#  ['I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O'],
#  ['I-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['I-PER', 'O'],
#  ...]

# %%
gold_tags
# Out:
# [['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-MISC',
#   'I-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MISC',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-ORG', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'B-ORG', 'O', 'O'],
#  ['B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'B-MISC', 'O'],
#  ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG'],
#  ['O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'B-LOC'],
#  ['O', 'O', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O', 'O', 'O', 'B-ORG'],
#  ['O', 'O', 'O', 'B-ORG'],
#  ['O', 'O', 'O', 'B-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-ORG', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'B-ORG', 'O', 'B-ORG', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG'],
#  ['O', 'O', 'O', 'B-LOC'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'B-LOC', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'B-LOC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O', 'B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-LOC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'B-ORG', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-MISC', 'I-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-MISC', 'I-MISC'],
#  ['B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['B-ORG', 'B-MISC', 'I-MISC', 'B-PER', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O'],
#  ['O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER'],
#  ['O', 'B-PER', 'I-PER'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-PER', 'I-PER'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'B-LOC', 'O', 'B-PER', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O'],
#  ['B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['B-MISC',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'B-MISC'],
#  ['B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['O', 'B-LOC', 'O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER'],
#  ['B-PER', 'O', 'B-LOC', 'O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'B-ORG', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
# ...
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-PER', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-PER', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'B-ORG', 'O'],
#  ['B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O'],
#  ['B-PER', 'O', 'B-MISC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ...]
